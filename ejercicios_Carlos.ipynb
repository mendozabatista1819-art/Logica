# %% [markdown]
# <a href="https://colab.research.google.com/github/mendozabatista1819-art/Logica/blob/main/ejercicios_Carlos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ejercico 4
edad_juan = int(input("¿Cual es la edad de Juan?}"))
edad_alberto = (2/3) * edad_juan
edad_ana = (4/3) * edad_juan
edad_mama = edad_juan + edad_alberto + edad_ana
print("la edad de juan es: ", edad_juan)
print("la edad de alberto es:",edad_alberto)
print("le edad de ana es ",edad_ana)
print("la edad de mama es: ",edad_mama)
# Out:
# ¿Cual es la edad de Juan?}9
# la edad de juan es:  9
# la edad de alberto es: 6.0
# le edad de ana es  12.0
# la edad de mama es:  27.0

# %% [markdown]
# Ejercicio 5
#
# suma = 0
#
# X = 20
#
# SUMA = SUMA + X
#
# SUMA = 0 + 20
#
# SUMA = 20
#
# Y = 40
#
# X = X + Y ** 2
#
# X = 20 + 40 ** 2
#
# X = 20 + 1600
#
# X = 1620
#
# SUMA = SUMA + X/Y
#
# SUMA = 20 + 1620/40
#
# SUMA = 20 + 40.5
#
# SUMA = 60.5
#
# EL RESULTADO ES 60.5

# %%
Ejercio 12

horas_trabajadas = 48
pago_hora = 5000
porcentaje_retencion = 0.125

salario_bruto = horas_trabajadas * pago_hora
retencion = salario_bruto * porcentaje_retencion
salario_neto = salario_bruto - retencion

print("el salario bruto es: $", salario_bruto)
print("la retencion en la fuente es: $", retencion)
print("el salio neto es: $", salario_neto)
# Out:
# el salario bruto es: $ 240000
# la retencion en la fuente es: $ 30000.0
# el salio neto es: $ 210000.0

# %% [markdown]
#  Inicio Algoritmo AreaRectangulo
#
#     Definir base, altura, area Como Real
#
#     Escribir "Ingrese la base:"
#     Leer base
#
#     Escribir "Ingrese la altura:"
#     Leer altura
#
#     area <- base * altura
#
#     Escribir "El área es: ", area
#
# FinAlgoritmo

# %% [markdown]
# Algoritmo LongitudCircunferencia
#
#     Definir radio, longitud Como Real
#     Definir pi Como Real
#
#     pi <- 3.1416
#
#     Escribir "Ingrese el radio del círculo:"
#     Leer radio
#
#     longitud <- 2 * pi * radio
#
#     Escribir "La longitud de la circunferencia es: ", longitud
#
# FinAlgoritmo
