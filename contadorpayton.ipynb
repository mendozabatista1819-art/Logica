# %% [markdown]
# <a href="https://colab.research.google.com/github/mendozabatista1819-art/Logica/blob/main/contadorpayton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
contador = 1

while contador <= 10:
  print ("contador:" + str (contador ))
  contador +=1
# Out:
# contador:1
# contador:2
# contador:3
# contador:4
# contador:5
# contador:6
# contador:7
# contador:8
# contador:9
# contador:10

# %%
contadorPares = 0
numero = int (input("ingcontadorParesrese un numero (0 - 1 para salir ):"))
while numero != -1 :
 if numero % 2 == 0 :
  contadorPares += 1

numero = int(input("ingrese un numero (0 - 1 para salir ):"))

print ("has ingresado" + str (contadorPares)+ " numeros pares")

# %%
contadorPares = 0
numero = int (input("ingcontadorParesrese un numero (0 - 1 para salir ):"))
while numero <= numero2:
 if numero % 2 == 0 :
  contadorPares += 1

numero = int(input("ingrese un numero (0 - 1 para salir ):"))

print ("has ingresado" + str (contadorPares)+ " numeros pares")

# %%
total = 0

i  =  1
while i <= 5:
  numero = int(input ("ingrese el numero: "))
  total += numero
  i +=1
print ("la suma de los numeros ingresados es: " + str (total))

# %%
sumaCalificaciones = 0

i + 1
while i <= 3:
  calificacion = float(input("ingrese la calificacion:"))
  sumaCalificacion += calificacion
  i += 1

  promedio = sumaCalificaciones / 3

print("el promedio de las calificaciones es: " + str(promedio))
