# %% [markdown]
# <a href="https://colab.research.google.com/github/mendozabatista1819-art/Logica/blob/main/vectores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

vector1= np . array ([1,2,3])
vector2 = np . array ([4,5,6])
print = vector1
print=vector2

# %%
primervalor= int (input("ingrese el primer valor"))
segundovalor= int (input("ingrese el segundo valor"))
tercervalor= int (input("ingrese el tercer valor"))

vector=[]
vector = np.append,(vector,[primervalor, segundovalor, tercervalor])
print (vector)
# Out:
# ingrese el primer valor1
# ingrese el segundo valor2
# ingrese el tercer valor3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5199/588931957.py in <cell line: 0>()
#       4
#       5 vector=[]
# ----> 6 vector = np.append,(vector[primervalor, segundovalor, tercervalor])
#       7 print (vector)
#
# NameError: name 'np' is not defined

# %%
import numpy as np
primervalor= int (input("ingrese el primer valor"))
segundovalor= int (input("ingrese el segundo valor"))
tercervalor=4

vector= np.append
